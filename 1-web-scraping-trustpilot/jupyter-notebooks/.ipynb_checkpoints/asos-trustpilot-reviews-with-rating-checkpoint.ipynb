# %%
# Import the libraries

from bs4 import BeautifulSoup
import pandas as pd
import json
import requests
from random import randint
import time
import re
import csv

# %%
# Create data storage

pages = []
review = []
date = []
stars = []

# I am using a for loop to iterate through the pages and save the date and review information in the lists

url = 'https://www.trustpilot.com/review/www.asos.com'
for i in range(1000):
    pg = url + '?page=' + str(i)
    r = requests.get(pg)
    soup = BeautifulSoup(r.text, 'lxml')

    print("Status code: " + str(r.status_code))     # Ensure that we are able to download data from all pages

    # store response into "pages" list
    pages.append(r)

    # adding wait time:
    wait_time = randint(1,4)
    print("I will sleep for " + str(wait_time) + " second/s.")
    time.sleep(wait_time)
    
    for star in soup.find_all("section", {"class":"review__content"}):
        rating = star.find("div", {"class":"star-rating star-rating--medium"}).find('img').get('alt')
        stars.append(rating)
            
    for i in range(len(soup.select("div.review-content__body"))):
        date.append(soup.select("div.review-content__header")[i].get_text())
        review.append(soup.select("div.review-content__body")[i].get_text())
# Out:
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 2 second/s.

# %%
# Extract the date using regex

clean_date = []
for string in date:
    clean_date.append(re.findall(r'\d{4}-\d{2}-\d{2}', string))
#clean_date

# %%
# Save only the first date in a new list

final_date = []
for i in range(len(clean_date)):
    final_date.append(clean_date[i][0])

# %%
#final_date

# %%
# Clean extracted reviews and save in a new list

clean_review = []
for string in review:
    clean_review.append(string.strip())
#clean_review

# %%
# Save reviews in a dataframe

asos_reviews = pd.DataFrame({"date": final_date,
                             "review": clean_review,
                            "rating": stars})

# %%
asos_reviews
# Out:
#              date                                             review  \
# 0      2020-12-09  Cristy was amazing\n                \n\n\n    ...
# 1      2020-12-09  Unhappy customer\n                \n\n\n      ...
# 2      2020-12-09  Still Waiting\n                \n\n\n         ...
# 3      2020-12-09  Great after sales support\n                \n\...
# 4      2020-12-09  Michael was very polite and helpful…\n        ...
# ...           ...                                                ...
# 19995  2020-01-24  Very short waiting time\n                \n\n\...
# 19996  2020-01-24  great\n                \n\n\n                S...
# 19997  2020-01-24  Qasim was amazing and genuine\n               ...
# 19998  2020-01-24  Excellent customer service\n                \n...
# 19999  2020-01-24  Ben was such a good help\n                \n\n...
#
#                    rating
# 0      5 stars: Excellent
# 1             1 star: Bad
# 2           2 stars: Poor
# 3      5 stars: Excellent
# 4      5 stars: Excellent
# ...                   ...
# 19995  5 stars: Excellent
# 19996  5 stars: Excellent
# 19997  5 stars: Excellent
# 19998  5 stars: Excellent
# 19999  5 stars: Excellent
#
# [20000 rows x 3 columns]

# %%
# Remove whitespces and newline from the reviews using regex

asos_reviews = asos_reviews.replace(to_replace=[r"\\t|\\n|\\r", "\t|\n|\r"], value = ["",""], regex = True)

# %%
# Save dataframe as a csv file

asos_reviews.to_csv('asos_reviews_with_rating.csv')
